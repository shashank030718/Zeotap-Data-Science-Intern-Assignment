# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Datasets
customers = pd.read_csv("Customers.csv")
products = pd.read_csv("Products.csv")
transactions = pd.read_csv("Transactions.csv")

# %%
#Display the first 10 rows of each dataset
print("Customers:")
display(customers.head(10)) #you can change row using head() 

print("Products:")
display(products.head(10))

print("Transactions:")
display(transactions.head(10))
# Out:
# Customers:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15
# 5      C0006     Brittany Palmer  South America  2024-01-07
# 6      C0007         Paul Graves           Asia  2022-06-18
# 7      C0008            David Li  North America  2024-01-13
# 8      C0009           Joy Clark         Europe  2023-08-14
# 9      C0010           Aaron Cox         Europe  2022-12-15
# Products:
#   ProductID                  ProductName     Category   Price
# 0      P001         ActiveWear Biography        Books  169.30
# 1      P002        ActiveWear Smartwatch  Electronics  346.30
# 2      P003      ComfortLiving Biography        Books   44.12
# ...

# %%
#shape of  datasets
print("\nShape of Datasets:")
print("Customers:", customers.shape)
print("Products:", products.shape)
print("Transactions:", transactions.shape)
# Out:
# Shape of Datasets:
# Customers: (200, 4)
# Products: (100, 4)
# Transactions: (1000, 7)

# %%
#information of datasets
print("\nInfo of Customers dataset:")
customers.info()

print("\nInfo of Products dataset:")
products.info()

print("\nInfo of Transactions dataset:")
transactions.info()
# Out:
# Info of Customers dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    200 non-null    object
#  1   CustomerName  200 non-null    object
#  2   Region        200 non-null    object
#  3   SignupDate    200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB
#
# Info of Products dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Category     100 non-null    object
#  3   Price        100 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
#
# Info of Transactions dataset:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
print("\nDescribe Customers dataset:")
display(customers.describe(include='all'))

print("\nDescribe Products dataset:")
display(products.describe(include='all'))

print("\nDescribe Transactions dataset:")
display(transactions.describe(include='all'))
# Out:
# Describe Customers dataset:
#        CustomerID      CustomerName         Region  SignupDate
# count         200               200            200         200
# unique        200               200              4         179
# top         C0001  Lawrence Carroll  South America  2024-11-11
# freq            1                 1             59           3
# Describe Products dataset:
#        ProductID            ProductName Category       Price
# count        100                    100      100  100.000000
# unique       100                     66        4         NaN
# top         P001  ActiveWear Smartwatch    Books         NaN
# freq           1                      4       26         NaN
# mean         NaN                    NaN      NaN  267.551700
# std          NaN                    NaN      NaN  143.219383
# min          NaN                    NaN      NaN   16.080000
# 25%          NaN                    NaN      NaN  147.767500
# ...

# %%
customers['SignupDate'] = pd.to_datetime(customers['SignupDate'])
transactions['TransactionDate'] = pd.to_datetime(transactions['TransactionDate'])

# %%
#Merge Dataset
data = transactions.merge(customers, on='CustomerID').merge(products, on='ProductID')

# %%
print("Dataset Overview:")
print(data.info(), "\n")

print("Missing Values:\n")
print(data.isnull().sum(), "\n")
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   datetime64[ns]
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   datetime64[ns]
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
#  12  Price_y          1000 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(7)
# memory usage: 109.4+ KB
# None
#
# Missing Values:
#
# TransactionID      0
# ...

# %%
#Customer Distribution by Region
region_counts = customers['Region'].value_counts()
region_counts.plot(kind='bar', title='Customer Distribution by Region', color='skyblue')
plt.ylabel('Number of Customers')
plt.show()

# %%
# 2. Top 10 Products by Revenue
data['Revenue'] = data['Price_y']
tp = data.groupby('ProductName')['Revenue'].sum().nlargest(10)
tp.plot(kind='bar', title='Top 10 Products by Revenue', color='lightgreen')
plt.ylabel('Revenue (USD)')
plt.show()

# %%
# 3. least 10 Products by Revenue
data['Revenue'] = data['Price_x']
tp = data.groupby('ProductName')['Revenue'].sum().nsmallest(10) #tp(Top Products)
tp = top_products.sort_values(ascending=False)
tp.plot(kind='bar', title='Least 10 Products by Revenue', color='lightcoral')
plt.ylabel('Revenue (USD)')
plt.show()

# %%
#4 Sales Trend
data['MonthYear'] = data['TransactionDate'].dt.to_period('M')
monthly_sales = data.groupby('MonthYear')['Revenue'].sum()
monthly_sales.plot(kind='line', title='Monthly Sales Trend', marker='*', color='yellow')
plt.ylabel('Revenue (USD)')
plt.show()

# %%
# 5 Revenue by product category
category_revenue = data.groupby('Category')['Revenue'].sum()
ax = category_revenue.plot(kind='bar', title='Revenue by Product Category', color='orange')
for i, value in enumerate(category_revenue):
    ax.text(i, value + 10, f'{value:.2f}', ha='center', va='bottom', fontsize=10)

# Adding labels
plt.ylabel('Revenue (USD)')
plt.show()

# %%
# 6 Revenue Distribution
data['Revenue'] = data['Price_x']
data.groupby('ProductName')['Revenue'].sum().plot(kind='hist', bins=30, title='Revenue Distribution of Products', color='lightblue')
plt.xlabel('Revenue (USD)')
plt.show()

# %%
# 7 RPM 
recent_purchase = data.groupby('CustomerID')['TransactionDate'].max()
recent_purchase = (data['TransactionDate'].max() - recent_purchase).dt.days
frequency = data.groupby('CustomerID')['TransactionID'].count()
monetary = data.groupby('CustomerID')['Revenue'].sum()
rfm = pd.DataFrame({'Recency': recent_purchase, 'Frequency': frequency, 'Monetary': monetary})

print("\nRFM Sample:")
print(rfm.head(10))
# Out:
# RFM Sample:
#             Recency  Frequency  Monetary
# CustomerID
# C0001            55          5   1391.67
# C0002            25          4    835.68
# C0003           125          4    782.83
# C0004             4          8   1925.09
# C0005            54          3    874.81
# C0006            82          4   1328.14
# C0007           125          3   1050.06
# C0008            11         10   2311.60
# C0009            77          3    896.50
# C0010            41          4    613.08
